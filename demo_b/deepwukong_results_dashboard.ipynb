# %% [markdown]
# # DeepWuKong perturbation results
#
# This notebook is the presentation entry point for the archived `run_20260710` experiment. It reads the committed comparison table; Docker and a GPU are not needed to show the results.

# %%
from pathlib import Path
from demo_b.visualize_results import read_rows, render_report

run_dir = Path('outputs/run_20260710')
rows = read_rows(run_dir / 'prediction_comparison.csv')
render_report(rows, run_dir / 'dashboard.html', 'DeepWuKong perturbation report: run_20260710')
len(rows), sorted({row['action'] for row in rows})

# %% [markdown]
# ## Presentation flow
#
# 1. Open `outputs/run_20260710/dashboard.html`.
# 2. Begin with the four headline cards: 10 baseline samples, 23 successful variants, 0 label flips, and the largest probability shift.
# 3. Use the action checkboxes to compare `control_wrapper`, `dead_statement`, and `temp_variable_split`.
# 4. Highlight that graph sizes changed for every successful variant, yet the model label remained stable; the notable exception in score magnitude is `07_codexglue_devign_4012` with `dead_statement`.
